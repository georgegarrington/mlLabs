# %%
import pandas as pd

# %%
training_data = pd.read_csv("mediaeval-2015-trainingset.txt", delimiter = "\t")
test_data = pd.read_csv("mediaeval-2015-testset.txt", delimiter = "\t")

# %%
training_data[training_data["label"] == "fake"]
# Out:
#                   tweetId                                          tweetText  \
# 0      263046056240115712  ¿Se acuerdan de la película: “El día después d...
# 1      262995061304852481  @milenagimon: Miren a Sandy en NY!  Tremenda i...
# 2      262979898002534400  Buena la foto del Huracán Sandy, me recuerda a...
# 3      262996108400271360     Scary shit #hurricane #NY http://t.co/e4JLBUfH
# 4      263018881839411200  My fave place in the world #nyc #hurricane #sa...
# ...                   ...                                                ...
# 14272  443231991593304064  @BobombDom *slaps TweetDeck with the PigFish h...
# 14273  443086239127076865  New Species of Fish found in Brazil or just Re...
# 14274  442978105238753280  What do we call this? #pigFISH http: \/\/t.co\...
# 14275  442753479782989824  Pigfish ? E dopo il pescecane c'è il pesce mai...
# 14276  442700377860104192  For those who can't decide between fish or mea...
#
#            userId      imageId(s)         username  \
# 0        21226711  sandyA_fake_46          iAnnieM
# 1       192378571  sandyA_fake_09   CarlosVerareal
# 2       132303095  sandyA_fake_09      LucasPalape
# 3       241995902  sandyA_fake_29      Haaaaarryyy
# 4       250315890  sandyA_fake_15   princess__natt
# ...           ...             ...              ...
# 14272  2179310905      pigFish_01  Da_Vault_Hunter
# 14273   254843101      pigFish_01   DjSituation_RC
# 14274  2367553228      pigFish_01        Vivo1Vuyo
# 14275   603120231      pigFish_01      CosimoTarta
# 14276    25086784      pigFish_01         johnszim
#
#                               timestamp label
# 0        Mon Oct 29 22:34:01 +0000 2012  fake
# 1        Mon Oct 29 19:11:23 +0000 2012  fake
# 2        Mon Oct 29 18:11:08 +0000 2012  fake
# 3        Mon Oct 29 19:15:33 +0000 2012  fake
# 4        Mon Oct 29 20:46:02 +0000 2012  fake
# ...                                 ...   ...
# 14272  Tue Mar 11 03: 48: 36 +0000 2014  fake
# 14273  Mon Mar 10 18: 09: 26 +0000 2014  fake
# 14274  Mon Mar 10 10: 59: 45 +0000 2014  fake
# 14275  Sun Mar 09 20: 07: 10 +0000 2014  fake
# 14276  Sun Mar 09 16: 36: 09 +0000 2014  fake
#
# [6742 rows x 7 columns]

# %%
#given a tweet, return a tuple of a set of words of the hashtags and a set of normal words
def parse_tweet(tweet):
    
    #remove any hashtags 
    tweet = tweet.replace("#", "")
    
    tokens = []
    
    for tok in nltk.word_tokenize(tweet):
        
        
    
    return nltk.word_tokenize(tweet)

# %%
parse_tweet(string)
# Out:
# ['Scary', 'shit', 'hurricane', 'NY', 'http', ':', '//t.co/e4JLBUfH']

# %%
type(training_data)
# Out:
# pandas.core.frame.DataFrame

# %%
import nltk

nltk.download("punkt")
sentence = "The quick brown fox, jumped over the lazy dog"
tokens = nltk.word_tokenize(sentence)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/georgegarrington/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#remove any stop words from the tokens. Stop words are assumed to all be lowercase
def filter_tokens(tokens, stop_words):
    
    filtered_tokens = []
    
    for tok in tokens:
        lc = tok.lower()
        if(lc not in stop_words):
            filtered_tokens.append(lc)
    
    return filtered_tokens

# %%
from nltk.corpus import stopwords
nltk.download("stopwords")

#how to get stopwords in a language
stop_words_english=set(stopwords.words("english"))
stop_words_spanish=set(stopwords.words("spanish"))
print(stop_words_spanish)
# Out:
# {'estad', 'o', 'habida', 'hayan', 'seamos', 'eres', 'estaríais', 'yo', 'tuya', 'fuesen', 'porque', 'había', 'habré', 'estuvieron', 'estará', 'seré', 'unos', 'nuestro', 'fuésemos', 'hubiese', 'estéis', 'tenida', 'hubiésemos', 'estarías', 'seríais', 'algunas', 'las', 'son', 'ese', 'tú', 'mío', 'tanto', 'estos', 'habréis', 'estas', 'habrá', 'estaríamos', 'un', 'seréis', 'tengáis', 'estuviese', 'mucho', 'y', 'vosotros', 'es', 'habías', 'estuvo', 'esta', 'somos', 'nos', 'estuvisteis', 'entre', 'hayáis', 'tuvieras', 'hubieseis', 'hubo', 'suyo', 'tenga', 'tendrá', 'vuestra', 'sus', 'he', 'e', 'era', 'todos', 'tendré', 'mi', 'tendríais', 'habríamos', 'siente', 'suyas', 'estuviera', 'habéis', 'míos', 'fueron', 'les', 'habremos', 'tuviéramos', 'eran', 'todo', 'se', 'fueran', 'serían', 'contra', 'muy', 'hubieran', 'habrías', 'os', 'mías', 'no', 'ellas', 'nuestros', 'tuvierais', 'tenías', 'estuvieras', 'fuiste', 'hayamos', 'estás', 'hay', 'tendría', 'otro', 'fueses', 'algo', 'estaréis', 'eso', 'están', 'estuviéramos', 'hubieses', 'tenidas', 'hube', 'con', 'será', 'seáis', 'muchos', 'sentida', 'habrás', 'durante', 'vosotras', 'erais', 'estaremos', 'suyos', 'nosotros', 'seríamos', 'ti', 'fuéramos', 'eras', 'éramos', 'sentido', 'esa', 'tenemos', 'tendrían', 'fuimos', 'teníamos', 'sobre', 'los', 'hubiera', 'su', 'antes', 'tendrán', 'le', 'tuyas', 'tu', 'serías', 'me', 'habríais', 'estada', 'fui', 'estaría', 'esto', 'nuestra', 'estados', 'mis', 'seas', 'teníais', 'tuvo', 'quien', 'estés', 'hubiéramos', 'tienes', 'estemos', 'otros', 'tenían', 'estuve', 'sintiendo', 'estarían', 'poco', 'sentidas', 'ellos', 'hasta', 'estarán', 'seremos', 'tendrías', 'habíais', 'ya', 'tuyo', 'pero', 'una', 'estado', 'estadas', 'estuviste', 'estaré', 'tendrás', 'hubimos', 'estando', 'uno', 'soy', 'tendríamos', 'sois', 'tuviesen', 'suya', 'tuyos', 'mía', 'también', 'serán', 'esos', 'tuviera', 'sin', 'han', 'cual', 'estuvimos', 'de', 'ella', 'cuando', 'tiene', 'estuvieseis', 'tuvieron', 'al', 'sería', 'estuvieses', 'vuestro', 'ante', 'sentid', 'hubierais', 'tuvieses', 'esas', 'nuestras', 'tuviese', 'por', 'habidas', 'fueseis', 'hubieron', 'donde', 'hubiesen', 'habíamos', 'estuviesen', 'estaba', 'que', 'tendremos', 'tus', 'teniendo', 'este', 'estarás', 'lo', 'habían', 'habidos', 'sí', 'otra', 'del', 'ha', 'hayas', 'vuestras', 'estáis', 'tenidos', 'estamos', 'habrán', 'tuvieran', 'nosotras', 'estuviésemos', 'tuviste', 'haya', 'está', 'fue', 'has', 'hubisteis', 'tengan', 'como', 'hemos', 'algunos', 'tuvieseis', 'serás', 'más', 'fuese', 'sea', 'habrían', 'tuve', 'desde', 'tuvimos', 'sentidos', 'fuerais', 'tuvisteis', 'para', 'estoy', 'fuera', 'tengamos', 'habido', 'qué', 'nada', 'hubieras', 'ni', 'estén', 'vuestros', 'tened', 'el', 'tienen', 'él', 'te', 'esté', 'sean', 'a', 'estabais', 'habiendo', 'tenéis', 'otras', 'estabas', 'estaban', 'hubiste', 'mí', 'habría', 'la', 'tengo', 'tendréis', 'tenido', 'estábamos', 'en', 'quienes', 'tengas', 'tuviésemos', 'fueras', 'estuvieran', 'fuisteis', 'estar', 'tenía', 'estuvierais'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/georgegarrington/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.stem import PorterStemmer

#stem the words into a single form
def stem(unstemmed):

    ps = PorterStemmer()
    stemmed = []
    
    for word in stemmed:
        stemmed.append(ps.stem(word))
    
    return stemmed

# %%
class TweetTokenizer:
    
    #by default the stop words are english and spanish
    stop_words = set(stopwords.words("english") + stopwords.words("spanish"))
    
    def tokenize(self, tweet):
        
        filtered_tokens = filter_tokens(tweet, stop_words)
        print("the filtered tokens are: ", filtered_tokens)
        output = []
        
        for tok in filtered_tokens:
        
            output.append(tok)
            
        return output
        
        #return map(stem, filtered_tokens)

# %%
t = TweetTokenizer()
string = training_data.tweetText[3]
nltk.word_tokenize(string)
# Out:
# ['Scary', 'shit', '#', 'hurricane', '#', 'NY', 'http', ':', '//t.co/e4JLBUfH']

# %%
from nltk.tokenize import TweetTokenizer

tzr = TweetTokenizer(preserve_case = False, reduce_len = True, strip_handles = True)
tokens = tzr.tokenize(string)

#given an nltk tokenized tweet, a list of stop words and a stemmer, stem the tokens, 
#remove prefix hashtags from tokens and also discard any link tokens or stop words
def simplify_tweet(tokenized_tweet, stop_words, ps):

    output = set()
    for tok in tokenized_tweet:
        
        #discard any links
        if(tok[:4] == "http" or tok in stop_words):
            continue;
        
        #If there is a prefix hashtag remove it
        if(tok[0] == '#'):
            tok = tok[1:]
        
        #stem the token
        output.add(ps.stem(tok))

    return output

print("The original is: " + string)
print("The tokens are: ", tokens)
# Out:
# The original is: Scary shit #hurricane #NY http://t.co/e4JLBUfH
# The tokens are:  ['scary', 'shit', '#hurricane', '#ny', 'http://t.co/e4JLBUfH']

# %%
ps = PorterStemmer()
english_stop_words = set(stopwords.words("english"))

test = simplify_tweet(tokens, english_stop_words, ps)
# Out:
# My test is: {'hurrican', 'scari', 'ny', 'shit'}

# %%
training_data.tweetText
# Out:
# 0        ¿Se acuerdan de la película: “El día después d...
# 1        @milenagimon: Miren a Sandy en NY!  Tremenda i...
# 2        Buena la foto del Huracán Sandy, me recuerda a...
# 3           Scary shit #hurricane #NY http://t.co/e4JLBUfH
# 4        My fave place in the world #nyc #hurricane #sa...
#                                ...
# 14272    @BobombDom *slaps TweetDeck with the PigFish h...
# 14273    New Species of Fish found in Brazil or just Re...
# 14274    What do we call this? #pigFISH http: \/\/t.co\...
# 14275    Pigfish ? E dopo il pescecane c'è il pesce mai...
# 14276    For those who can't decide between fish or mea...
# Name: tweetText, Length: 14277, dtype: object

# %%
from langdetect import detect

# %%
modified = del training_data["tweetId", "userId", "imageId(s)", "username", "timestamp", "label"]
# Out:
#   File "<ipython-input-115-dd9e090bdbcc>", line 1
#     modified = del training_data["tweetId", "userId", "imageId(s)", "username", "timestamp", "label"]
#                ^
# SyntaxError: invalid syntax

# %%
modified = training_data.drop(["tweetId", "userId", "imageId(s)", "username", "timestamp"], axis = 1)
modified
# Out:
#                                                tweetText label
# 0      ¿Se acuerdan de la película: “El día después d...  fake
# 1      @milenagimon: Miren a Sandy en NY!  Tremenda i...  fake
# 2      Buena la foto del Huracán Sandy, me recuerda a...  fake
# 3         Scary shit #hurricane #NY http://t.co/e4JLBUfH  fake
# 4      My fave place in the world #nyc #hurricane #sa...  fake
# ...                                                  ...   ...
# 14272  @BobombDom *slaps TweetDeck with the PigFish h...  fake
# 14273  New Species of Fish found in Brazil or just Re...  fake
# 14274  What do we call this? #pigFISH http: \/\/t.co\...  fake
# 14275  Pigfish ? E dopo il pescecane c'è il pesce mai...  fake
# 14276  For those who can't decide between fish or mea...  fake
#
# [14277 rows x 2 columns]

# %%
# VERSION 1 USING STEMMING




from langdetect import detect

#illegal as this is the key corresponding to porter stemmer I think which we are not using
snowball_langs = list(SnowballStemmer.languages)
langdetect_langs = ["ar", "da", "nl", "en", "fi", "fr", "de", "hu", "it", "no", "illegal", "pt", "ro", "ru", "es", "sv"]
lang_dict = dict(zip(langdetect_langs, snowball_langs))

#given an nltk tokenized tweet, a list of stop words and a stemmer, stem the tokens, 
#remove prefix hashtags from tokens and also discard any link tokens or stop words
#return the simplified tweet paired with the estimated language
def handle_tweet(tweet):
    
    #tokenizer the tweet with a TWEET TOKENIZER
    tokens = tzr.tokenize(tweet)
    
    #Keep track of the number of tokens (possibly) detected in each language. Assume that
    #the tweet is in the language with the most tokens seen
    langs_seen = {}
    
    filtered_toks = set()
    
    #remove punctuation and digits
    for tok in tokens:
    
        #If there is a prefix hashtag remove it
        if tok[0] == '#':
            tok = tok[1:]
        
        #discard non alphanumeric strings and digits
        if not tok.isalnum() or tok.isdigit():
            continue;
            
        filtered_toks.add(tok)
    
    #first determine the language
    for tok in filtered_toks:
        
        #if the token language cannot be detectected then label as unknown
        try:
            #print("The token is:",tok)
            guess = detect(tok)
            #print("My guess is:",guess)
        except:
            guess = "unknown"
            
        if guess in langs_seen:
            langs_seen[guess] += 1
        else:
            langs_seen[guess] = 1
        
    #the most common language guess seen
    predicted_language = max(langs_seen, key=langs_seen.get)
    print("The original tweet was:", tweet,"\n")
    #print("The tokens were:", filtered_toks)
    print("The language guesses were:",langs_seen)
    print("I predicted the language:",predicted_language,"\n")
    output = set()
    
    #print("Does snowball stemmer support it?")
    
    #only stem the tokens if snowball stemmer supports the language
    if predicted_language in lang_dict.keys():
    
        #print("Yes it does")
    
        stop_words = stopwords.words(lang_dict[predicted_language])
        stemmer = SnowballStemmer(lang_dict[predicted_language])
    
        #now remove stopwords, links, hashtags and stem the words
        for tok in filtered_toks:
            
            #discard any non alphanumeric tokens or stopwords
            if(tok in stop_words):
                continue;

            #stem the token with it's language specific stemmer
            output.add(stemmer.stem(tok))
    
    else:
        
        print("(Unsupported by snowball stem)")
        return None
        #output = filtered_toks
        #print("No it doesn't")
            
    # LOOK ABOVE AND BELOW ME, should change this so you stem the language with the stemmer 
    # for the language it is detected in
        
    return output

# %%
for i in range(10):

    print("---- INDEX",i,"----\n\n")
    result = handle_tweet(modified["tweetText"][i])
    print("result:",result)
    print("\n\n")
# Out:
# ---- INDEX 0 ----
#
#
# The original tweet was: ¿Se acuerdan de la película: “El día después de mañana”? Me recuerda a lo que está pasando con el huracán #Sandy. http://t.co/JQQeRPwN
#
# The language guesses were: {'es': 10, 'fr': 1, 'tl': 3, 'ca': 1, 'id': 2, 'vi': 1, 'it': 1}
# I predicted the language: es
#
# result: {'pas', 'dia', 'mañan', 'sandy', 'acuerd', 'huracan', 'recuerd', 'pelicul', 'despues'}
#
#
#
# ---- INDEX 1 ----
#
#
# The original tweet was: @milenagimon: Miren a Sandy en NY!  Tremenda imagen del huracán. Parece el "Día de la Independencia 2" http://t.co/41jUweux REAL! RT.
#
# The language guesses were: {'ro': 2, 'es': 4, 'ca': 1, 'tl': 2, 'fr': 2, 'nl': 2, 'de': 1, 'vi': 1, 'sw': 1, 'tr': 1}
# I predicted the language: es
#
# result: {'real', 'parec', 'mir', 'tremend', 'sandy', 'rt', 'huracan', 'independent', 'imag', 'dia', 'ny'}
#
#
#
# ---- INDEX 2 ----
#
#
# The original tweet was: Buena la foto del Huracán Sandy, me recuerda a la película Día de la Independencia #ID4 #Sandy  http://t.co/PTdAXABZ
#
# The language guesses were: {'es': 5, 'ca': 1, 'tl': 2, 'nl': 1, 'cy': 1, 'id': 2, 'vi': 1, 'no': 1}
# I predicted the language: es
#
# result: {'fot', 'buen', 'sandy', 'huracan', 'independent', 'id4', 'dia', 'recuerd', 'pelicul'}
#
#
#
# ---- INDEX 3 ----
#
#
# The original tweet was: Scary shit #hurricane #NY http://t.co/e4JLBUfH
#
# The language guesses were: {'en': 2, 'sw': 1, 'sq': 1}
# I predicted the language: en
#
# result: {'hurrican', 'scari', 'ny', 'shit'}
#
#
#
# ---- INDEX 4 ----
#
#
# The original tweet was: My fave place in the world #nyc #hurricane #sandy #statueofliberty 🗽 http://t.co/Ex61doZk
#
# The language guesses were: {'no': 1, 'es': 1, 'tl': 1, 'af': 2, 'fi': 1, 'pl': 1, 'en': 3}
# I predicted the language: en
#
# result: {'fave', 'place', 'world', 'nyc', 'hurrican', 'statueofliberti', 'sandi'}
#
#
#
# ---- INDEX 5 ----
#
#
# The original tweet was: 42nd #time #square #NYC #subway #hurricane http://t.co/daX5YY7X
#
# The language guesses were: {'so': 1, 'sq': 2, 'pl': 1, 'ca': 1, 'en': 1}
# I predicted the language: sq
#
# (Unsupported by snowball stem)
# result: None
#
#
#
# ---- INDEX 6 ----
#
#
# The original tweet was: Just in time for #halloween a photo of #hurricane #sandy #frankenstorm http://t.co/xquKB4VN
#
# The language guesses were: {'da': 2, 'tl': 2, 'af': 1, 'cs': 1, 'en': 3, 'sq': 1, 'et': 1}
# I predicted the language: en
#
# result: {'frankenstorm', 'halloween', 'photo', 'time', 'hurrican', 'sandi'}
#
#
#
# ---- INDEX 7 ----
#
#
# The original tweet was: Crazy pic of #Hurricane #Sandy prayers go out to family and friends on the East Coast http://t.co/c4sceiMt
#
# The language guesses were: {'da': 1, 'en': 8, 'pl': 1, 'tl': 1, 'fr': 1, 'it': 1, 'cy': 1, 'ro': 1, 'fi': 1}
# I predicted the language: en
#
# result: {'crazi', 'famili', 'hurrican', 'east', 'pic', 'prayer', 'go', 'friend', 'coast', 'sandi'}
#
#
#
# ---- INDEX 8 ----
#
#
# The original tweet was: #sandy #newyork #hurricane #statueofliberty #USA http://t.co/iQfEbO1E
#
# The language guesses were: {'tl': 1, 'cy': 1, 'fi': 1, 'en': 2}
# I predicted the language: en
#
# result: {'newyork', 'usa', 'hurrican', 'statueofliberti', 'sandi'}
#
#
#
# ---- INDEX 9 ----
#
#
# The original tweet was: #nyc #hurricane http://t.co/Gv3QxZlq
#
# The language guesses were: {'pl': 1, 'en': 1}
# I predicted the language: pl
#
# (Unsupported by snowball stem)
# result: None

# %%
#VERSION 2 TRY AND DETECT THE LANGUAGE WITHOUT STEMMING
from langdetect import detect



snowball_langs = list(SnowballStemmer.languages)
langdetect_langs = ["ar", "da", "nl", "en", "fi", "fr", "de", "hu", "it", "no", "illegal", "pt", "ro", "ru", "es", "sv"]
lang_dict = dict(zip(langdetect_langs, snowball_langs))



#given an nltk tokenized tweet, a list of stop words and a stemmer, stem the tokens, 
#remove prefix hashtags from tokens and also discard any link tokens or stop words
#return the simplified tweet paired with the estimated language
def handle_tweet(tweet):
    
    #tokenizer the tweet with a TWEET TOKENIZER
    print("Going to tokenize the tweet:",tweet)
    tokens = tzr.tokenize(tweet)
    
    #Keep track of the number of tokens (possibly) detected in each language. Assume that
    #the tweet is in the language with the most tokens seen
    langs_seen = {}
    
    filtered_toks = set()
    
    #remove punctuation and digits
    for tok in tokens:
    
        #If there is a prefix hashtag remove it
        if tok[0] == '#':
            tok = tok[1:]
        
        #discard non alphanumeric strings and digits
        if not tok.isalnum() or tok.isdigit():
            continue;
            
        filtered_toks.add(tok)
    
    #first determine the language
    for tok in filtered_toks:
        
        #if the token language cannot be detectected then label as unknown
        try:
            #print("The token is:",tok)
            guess = detect(tok)
            #print("My guess is:",guess)
        except:
            guess = "unknown"
            
        if guess in langs_seen:
            langs_seen[guess] += 1
        else:
            langs_seen[guess] = 1
        
    #the most common language guess seen
    predicted_language = max(langs_seen, key=langs_seen.get)
    print("The original tweet was:", tweet,"\n")
    #print("The tokens were:", filtered_toks)
    print("The language guesses were:",langs_seen)
    print("I predicted the language:",predicted_language,"\n")
    output = set()
    
    #print("Does snowball stemmer support it?")
    
    #only remove stop words if we have predicted a supported language
    if predicted_language in lang_dict.keys():
    
        #print("Yes it does")
    
        stop_words = stopwords.words(lang_dict[predicted_language])
    
        #now remove stopwords, links, hashtags and stem the words
        for tok in filtered_toks:
            
            #discard any non alphanumeric tokens or stopwords
            if(tok in stop_words):
                continue;

            #stem the token with it's language specific stemmer
            output.add(tok)
    
    else:
        
        print("Returning the values:",filtered_toks,predicted_language)
        return filtered_toks
        #output = filtered_toks
        #print("No it doesn't")
            
    # LOOK ABOVE AND BELOW ME, should change this so you stem the language with the stemmer 
    # for the language it is detected in
        
    print("Returning the values:",output,predicted_language)
    return output

# %%
modified.loc[40]
# Out:
# tweetText    wow! #hurricane #Sandy over lady liberty  http...
# label                                                     fake
# Name: 40, dtype: object

# %%
import copy
import numpy as np

modified2 = copy.deepcopy(modified)

def myMethod():

    for i in range(modified2.size):

        print("---- INDEX",i,"----\n\n")
        tokens = handle_tweet(modified2["tweetText"][i])
        
        modified2.at[i] = tokens, modified2["label"][i]
        print("the old value of the row is: ", modified["tweetText"][i])
        print("the new value of the row is: ", modified2["tweetText"][i])
        print("result:",result)
        print("\n\n")

myMethod()
        
modified2
# Out:
# ---- INDEX 0 ----
#
#
# Going to tokenize the tweet: ¿Se acuerdan de la película: “El día después de mañana”? Me recuerda a lo que está pasando con el huracán #Sandy. http://t.co/JQQeRPwN
# The original tweet was: ¿Se acuerdan de la película: “El día después de mañana”? Me recuerda a lo que está pasando con el huracán #Sandy. http://t.co/JQQeRPwN
#
# The language guesses were: {'es': 10, 'fr': 1, 'tl': 3, 'ca': 1, 'id': 2, 'vi': 1, 'it': 1}
# I predicted the language: es
#
# Returning the values: {'película', 'sandy', 'mañana', 'después', 'día', 'pasando', 'recuerda', 'huracán', 'acuerdan'} es
# the old value of the row is:  {'película', 'sandy', 'mañana', 'después', 'día', 'pasando', 'recuerda', 'huracán', 'acuerdan'}
# the new value of the row is:  {'película', 'sandy', 'mañana', 'después', 'día', 'pasando', 'recuerda', 'huracán', 'acuerdan'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 1 ----
#
#
# Going to tokenize the tweet: @milenagimon: Miren a Sandy en NY!  Tremenda imagen del huracán. Parece el "Día de la Independencia 2" http://t.co/41jUweux REAL! RT.
# The original tweet was: @milenagimon: Miren a Sandy en NY!  Tremenda imagen del huracán. Parece el "Día de la Independencia 2" http://t.co/41jUweux REAL! RT.
#
# The language guesses were: {'ro': 2, 'es': 4, 'ca': 1, 'tl': 2, 'fr': 3, 'nl': 2, 'de': 1, 'vi': 1, 'sw': 1}
# I predicted the language: es
#
# Returning the values: {'real', 'ny', 'sandy', 'rt', 'tremenda', 'imagen', 'parece', 'huracán', 'día', 'miren', 'independencia'} es
# the old value of the row is:  {'real', 'ny', 'sandy', 'rt', 'tremenda', 'imagen', 'parece', 'huracán', 'día', 'miren', 'independencia'}
# the new value of the row is:  {'real', 'ny', 'sandy', 'rt', 'tremenda', 'imagen', 'parece', 'huracán', 'día', 'miren', 'independencia'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2 ----
#
#
# Going to tokenize the tweet: Buena la foto del Huracán Sandy, me recuerda a la película Día de la Independencia #ID4 #Sandy  http://t.co/PTdAXABZ
# The original tweet was: Buena la foto del Huracán Sandy, me recuerda a la película Día de la Independencia #ID4 #Sandy  http://t.co/PTdAXABZ
#
# The language guesses were: {'es': 5, 'ca': 1, 'tl': 2, 'nl': 1, 'cy': 1, 'id': 2, 'vi': 1, 'no': 1}
# I predicted the language: es
#
# Returning the values: {'foto', 'película', 'huracán', 'sandy', 'id4', 'recuerda', 'día', 'buena', 'independencia'} es
# the old value of the row is:  {'foto', 'película', 'huracán', 'sandy', 'id4', 'recuerda', 'día', 'buena', 'independencia'}
# the new value of the row is:  {'foto', 'película', 'huracán', 'sandy', 'id4', 'recuerda', 'día', 'buena', 'independencia'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 3 ----
#
#
# Going to tokenize the tweet: Scary shit #hurricane #NY http://t.co/e4JLBUfH
# The original tweet was: Scary shit #hurricane #NY http://t.co/e4JLBUfH
#
# The language guesses were: {'en': 2, 'sw': 1, 'sq': 1}
# I predicted the language: en
#
# Returning the values: {'scary', 'ny', 'shit', 'hurricane'} en
# the old value of the row is:  {'scary', 'ny', 'shit', 'hurricane'}
# the new value of the row is:  {'scary', 'ny', 'shit', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 4 ----
#
#
# Going to tokenize the tweet: My fave place in the world #nyc #hurricane #sandy #statueofliberty 🗽 http://t.co/Ex61doZk
# The original tweet was: My fave place in the world #nyc #hurricane #sandy #statueofliberty 🗽 http://t.co/Ex61doZk
#
# The language guesses were: {'no': 1, 'es': 1, 'tl': 1, 'af': 2, 'cy': 1, 'pl': 1, 'en': 3}
# I predicted the language: en
#
# Returning the values: {'fave', 'place', 'sandy', 'world', 'nyc', 'statueofliberty', 'hurricane'} en
# the old value of the row is:  {'fave', 'place', 'sandy', 'world', 'nyc', 'statueofliberty', 'hurricane'}
# the new value of the row is:  {'fave', 'place', 'sandy', 'world', 'nyc', 'statueofliberty', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 5 ----
#
#
# Going to tokenize the tweet: 42nd #time #square #NYC #subway #hurricane http://t.co/daX5YY7X
# The original tweet was: 42nd #time #square #NYC #subway #hurricane http://t.co/daX5YY7X
#
# The language guesses were: {'sw': 1, 'sq': 2, 'pl': 1, 'ca': 1, 'en': 1}
# I predicted the language: sq
#
# Returning the values: {'subway', '42nd', 'nyc', 'time', 'square', 'hurricane'} sq
# the old value of the row is:  {'subway', '42nd', 'nyc', 'time', 'square', 'hurricane'}
# the new value of the row is:  {'subway', '42nd', 'nyc', 'time', 'square', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 6 ----
#
#
# Going to tokenize the tweet: Just in time for #halloween a photo of #hurricane #sandy #frankenstorm http://t.co/xquKB4VN
# The original tweet was: Just in time for #halloween a photo of #hurricane #sandy #frankenstorm http://t.co/xquKB4VN
#
# The language guesses were: {'da': 2, 'tl': 2, 'af': 1, 'cs': 1, 'en': 3, 'sq': 1, 'et': 1}
# I predicted the language: en
#
# Returning the values: {'frankenstorm', 'sandy', 'photo', 'time', 'hurricane', 'halloween'} en
# the old value of the row is:  {'frankenstorm', 'sandy', 'photo', 'time', 'hurricane', 'halloween'}
# the new value of the row is:  {'frankenstorm', 'sandy', 'photo', 'time', 'hurricane', 'halloween'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 7 ----
#
#
# Going to tokenize the tweet: Crazy pic of #Hurricane #Sandy prayers go out to family and friends on the East Coast http://t.co/c4sceiMt
# The original tweet was: Crazy pic of #Hurricane #Sandy prayers go out to family and friends on the East Coast http://t.co/c4sceiMt
#
# The language guesses were: {'da': 1, 'en': 8, 'pl': 1, 'tl': 1, 'fr': 1, 'it': 1, 'cy': 1, 'ro': 1, 'fi': 1}
# I predicted the language: en
#
# Returning the values: {'family', 'prayers', 'crazy', 'sandy', 'east', 'pic', 'go', 'coast', 'friends', 'hurricane'} en
# the old value of the row is:  {'family', 'prayers', 'crazy', 'sandy', 'east', 'pic', 'go', 'coast', 'friends', 'hurricane'}
# the new value of the row is:  {'family', 'prayers', 'crazy', 'sandy', 'east', 'pic', 'go', 'coast', 'friends', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 8 ----
#
#
# Going to tokenize the tweet: #sandy #newyork #hurricane #statueofliberty #USA http://t.co/iQfEbO1E
# The original tweet was: #sandy #newyork #hurricane #statueofliberty #USA http://t.co/iQfEbO1E
#
# The language guesses were: {'tl': 1, 'cy': 1, 'fi': 1, 'en': 2}
# I predicted the language: en
#
# Returning the values: {'sandy', 'newyork', 'usa', 'statueofliberty', 'hurricane'} en
# the old value of the row is:  {'sandy', 'newyork', 'usa', 'statueofliberty', 'hurricane'}
# the new value of the row is:  {'sandy', 'newyork', 'usa', 'statueofliberty', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 9 ----
#
#
# Going to tokenize the tweet: #nyc #hurricane http://t.co/Gv3QxZlq
# The original tweet was: #nyc #hurricane http://t.co/Gv3QxZlq
#
# The language guesses were: {'pl': 1, 'en': 1}
# I predicted the language: pl
#
# Returning the values: {'nyc', 'hurricane'} pl
# the old value of the row is:  {'nyc', 'hurricane'}
# the new value of the row is:  {'nyc', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 10 ----
#
#
# Going to tokenize the tweet: robertosalibaba  god be with u brother #sandy #hurricane #newyork http://t.co/GXheTqlO
# The original tweet was: robertosalibaba  god be with u brother #sandy #hurricane #newyork http://t.co/GXheTqlO
#
# The language guesses were: {'id': 1, 'en': 3, 'es': 1, 'tl': 1, 'cy': 2, 'fr': 1}
# I predicted the language: en
#
# Returning the values: {'brother', 'robertosalibaba', 'sandy', 'god', 'newyork', 'u', 'hurricane'} en
# the old value of the row is:  {'brother', 'robertosalibaba', 'sandy', 'god', 'newyork', 'u', 'hurricane'}
# the new value of the row is:  {'brother', 'robertosalibaba', 'sandy', 'god', 'newyork', 'u', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 11 ----
#
#
# Going to tokenize the tweet: #Crazy #Hurricane #Sandy http://t.co/0zrMsgvs
# The original tweet was: #Crazy #Hurricane #Sandy http://t.co/0zrMsgvs
#
# The language guesses were: {'tl': 1, 'en': 1, 'pl': 1}
# I predicted the language: tl
#
# Returning the values: {'sandy', 'hurricane', 'crazy'} tl
# the old value of the row is:  {'sandy', 'hurricane', 'crazy'}
# the new value of the row is:  {'sandy', 'hurricane', 'crazy'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 12 ----
#
#
# Going to tokenize the tweet: #shark #newjersey #swim #sandy #hurricane  http://t.co/2i4WuGvP
# The original tweet was: #shark #newjersey #swim #sandy #hurricane  http://t.co/2i4WuGvP
#
# The language guesses were: {'so': 1, 'tl': 1, 'pl': 1, 'no': 1, 'en': 1}
# I predicted the language: so
#
# Returning the values: {'shark', 'sandy', 'swim', 'newjersey', 'hurricane'} so
# the old value of the row is:  {'shark', 'sandy', 'swim', 'newjersey', 'hurricane'}
# the new value of the row is:  {'shark', 'sandy', 'swim', 'newjersey', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 13 ----
#
#
# Going to tokenize the tweet: Good luck #ny #newyork #usa #hurricane #sandy http://t.co/0y435Anw
# The original tweet was: Good luck #ny #newyork #usa #hurricane #sandy http://t.co/0y435Anw
#
# The language guesses were: {'ro': 1, 'tl': 1, 'so': 1, 'cy': 1, 'fi': 1, 'sw': 1, 'en': 1}
# I predicted the language: ro
#
# Returning the values: {'luck', 'sandy', 'good', 'newyork', 'usa', 'ny', 'hurricane'} ro
# the old value of the row is:  {'luck', 'sandy', 'good', 'newyork', 'usa', 'ny', 'hurricane'}
# the new value of the row is:  {'luck', 'sandy', 'good', 'newyork', 'usa', 'ny', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 14 ----
#
#
# Going to tokenize the tweet: Wow.... Fishing anyone? #hurricane #sandy http://t.co/LS0Kx0zm
# The original tweet was: Wow.... Fishing anyone? #hurricane #sandy http://t.co/LS0Kx0zm
#
# The language guesses were: {'en': 2, 'tl': 2, 'pl': 1}
# I predicted the language: en
#
# Returning the values: {'fishing', 'sandy', 'wow', 'anyone', 'hurricane'} en
# the old value of the row is:  {'fishing', 'sandy', 'wow', 'anyone', 'hurricane'}
# the new value of the row is:  {'fishing', 'sandy', 'wow', 'anyone', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 15 ----
#
#
# Going to tokenize the tweet: Well #howdy there #hurricane #sandy . Just wanted to let you know that you took my power, internet, &amp;&amp; happi http://t.co/qKxLQEmT
# The original tweet was: Well #howdy there #hurricane #sandy . Just wanted to let you know that you took my power, internet, &amp;&amp; happi http://t.co/qKxLQEmT
#
# The language guesses were: {'pl': 1, 'en': 5, 'cy': 3, 'af': 2, 'fi': 1, 'tl': 1, 'fr': 1, 'sw': 1, 'et': 1, 'de': 1}
# I predicted the language: en
#
# Returning the values: {'well', 'wanted', 'know', 'happi', 'sandy', 'let', 'howdy', 'took', 'power', 'hurricane', 'internet'} en
# the old value of the row is:  {'well', 'wanted', 'know', 'happi', 'sandy', 'let', 'howdy', 'took', 'power', 'hurricane', 'internet'}
# the new value of the row is:  {'well', 'wanted', 'know', 'happi', 'sandy', 'let', 'howdy', 'took', 'power', 'hurricane', 'internet'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 16 ----
#
#
# Going to tokenize the tweet: Just known this bcs of #jason #chen updated the pic! Everyone be safe! #newyork #sandy #hurricane #nature #e http://t.co/c6VTaBkT
# The original tweet was: Just known this bcs of #jason #chen updated the pic! Everyone be safe! #newyork #sandy #hurricane #nature #e http://t.co/c6VTaBkT
#
# The language guesses were: {'hu': 1, 'en': 7, 'id': 1, 'de': 1, 'tl': 2, 'it': 1, 'cy': 2, 'fi': 1, 'et': 1, 'es': 1}
# I predicted the language: en
#
# Returning the values: {'bcs', 'updated', 'chen', 'nature', 'everyone', 'sandy', 'pic', 'safe', 'jason', 'newyork', 'e', 'known', 'hurricane'} en
# the old value of the row is:  {'bcs', 'updated', 'chen', 'nature', 'everyone', 'sandy', 'pic', 'safe', 'jason', 'newyork', 'e', 'known', 'hurricane'}
# the new value of the row is:  {'bcs', 'updated', 'chen', 'nature', 'everyone', 'sandy', 'pic', 'safe', 'jason', 'newyork', 'e', 'known', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 17 ----
#
#
# Going to tokenize the tweet: My thoughts and prayers go to all of the people going thru #hurricane #sandy #ct #de #ma #md #me #nc #nh #nj http://t.co/kvKzXOg1
# The original tweet was: My thoughts and prayers go to all of the people going thru #hurricane #sandy #ct #de #ma #md #me #nc #nh #nj http://t.co/kvKzXOg1
#
# The language guesses were: {'tr': 1, 'tl': 2, 'en': 8, 'vi': 1, 'cy': 3, 'so': 1, 'es': 1, 'sq': 1, 'sw': 1, 'it': 1, 'id': 1, 'ro': 1}
# I predicted the language: en
#
# Returning the values: {'nc', 'de', 'going', 'people', 'nh', 'prayers', 'sandy', 'thru', 'md', 'go', 'ct', 'thoughts', 'nj', 'hurricane'} en
# the old value of the row is:  {'nc', 'de', 'going', 'people', 'nh', 'prayers', 'sandy', 'thru', 'md', 'go', 'ct', 'thoughts', 'nj', 'hurricane'}
# the new value of the row is:  {'nc', 'de', 'going', 'people', 'nh', 'prayers', 'sandy', 'thru', 'md', 'go', 'ct', 'thoughts', 'nj', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 18 ----
#
#
# Going to tokenize the tweet: Stay safe my New York family...#nyc #newyork #storm #hurricane #wind http://t.co/iSdoZmLs
# The original tweet was: Stay safe my New York family...#nyc #newyork #storm #hurricane #wind http://t.co/iSdoZmLs
#
# The language guesses were: {'en': 2, 'tr': 1, 'pl': 2, 'cy': 4, 'sk': 1, 'tl': 1}
# I predicted the language: cy
#
# Returning the values: {'hurricane', 'york', 'wind', 'my', 'safe', 'nyc', 'newyork', 'family', 'new', 'storm', 'stay'} cy
# the old value of the row is:  {'hurricane', 'york', 'wind', 'my', 'safe', 'nyc', 'newyork', 'family', 'new', 'storm', 'stay'}
# the new value of the row is:  {'hurricane', 'york', 'wind', 'my', 'safe', 'nyc', 'newyork', 'family', 'new', 'storm', 'stay'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 19 ----
#
#
# Going to tokenize the tweet: New York #hurricane #Sandy http://t.co/AnrR8u7t
# The original tweet was: New York #hurricane #Sandy http://t.co/AnrR8u7t
#
# The language guesses were: {'tr': 1, 'cy': 1, 'en': 1, 'tl': 1}
# I predicted the language: tr
#
# Returning the values: {'york', 'new', 'hurricane', 'sandy'} tr
# the old value of the row is:  {'york', 'new', 'hurricane', 'sandy'}
# the new value of the row is:  {'york', 'new', 'hurricane', 'sandy'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 20 ----
#
#
# Going to tokenize the tweet: Probably the coolest pic of #hurricanesandy! #hurricane #sandy #weather #storm #statueofliberty http://t.co/RCf5ZKrn
# The original tweet was: Probably the coolest pic of #hurricanesandy! #hurricane #sandy #weather #storm #statueofliberty http://t.co/RCf5ZKrn
#
# The language guesses were: {'en': 6, 'sk': 1, 'tl': 1, 'cs': 1, 'it': 1, 'fr': 1}
# I predicted the language: en
#
# Returning the values: {'weather', 'hurricanesandy', 'coolest', 'sandy', 'probably', 'pic', 'statueofliberty', 'storm', 'hurricane'} en
# the old value of the row is:  {'weather', 'hurricanesandy', 'coolest', 'sandy', 'probably', 'pic', 'statueofliberty', 'storm', 'hurricane'}
# the new value of the row is:  {'weather', 'hurricanesandy', 'coolest', 'sandy', 'probably', 'pic', 'statueofliberty', 'storm', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 21 ----
#
#
# Going to tokenize the tweet: Crazy #sandy #hurricane images. Be glad we live in the #west coast. http://t.co/c2wYXDao
# The original tweet was: Crazy #sandy #hurricane images. Be glad we live in the #west coast. http://t.co/c2wYXDao
#
# The language guesses were: {'id': 1, 'da': 1, 'pl': 2, 'cy': 1, 'tl': 1, 'af': 2, 'ro': 1, 'en': 2, 'de': 1}
# I predicted the language: pl
#
# Returning the values: {'be', 'live', 'crazy', 'glad', 'we', 'sandy', 'in', 'west', 'coast', 'the', 'hurricane', 'images'} pl
# the old value of the row is:  {'be', 'live', 'crazy', 'glad', 'we', 'sandy', 'in', 'west', 'coast', 'the', 'hurricane', 'images'}
# the new value of the row is:  {'be', 'live', 'crazy', 'glad', 'we', 'sandy', 'in', 'west', 'coast', 'the', 'hurricane', 'images'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 22 ----
#
#
# Going to tokenize the tweet: My cousin sent this to me... :: Cleveland voice :: We gon' die!!! ☁⚡☔🌊 #hurricane #hurricanesandy #sandy http://t.co/XtW4exLn
# The original tweet was: My cousin sent this to me... :: Cleveland voice :: We gon' die!!! ☁⚡☔🌊 #hurricane #hurricanesandy #sandy http://t.co/XtW4exLn
#
# The language guesses were: {'fr': 1, 'en': 5, 'pl': 1, 'tl': 1, 'cy': 2, 'no': 1, 'cs': 1, 'af': 1, 'id': 1}
# I predicted the language: en
#
# Returning the values: {'cousin', 'hurricanesandy', 'sandy', 'cleveland', 'gon', 'sent', 'voice', 'die', 'hurricane'} en
# the old value of the row is:  {'cousin', 'hurricanesandy', 'sandy', 'cleveland', 'gon', 'sent', 'voice', 'die', 'hurricane'}
# the new value of the row is:  {'cousin', 'hurricanesandy', 'sandy', 'cleveland', 'gon', 'sent', 'voice', 'die', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 23 ----
#
#
# Going to tokenize the tweet: We forget tomb unknown soldier is guard 24/7365 ! Taken today #hurricane #sandy #frankenstorm http://t.co/mFEfmCMk
# The original tweet was: We forget tomb unknown soldier is guard 24/7365 ! Taken today #hurricane #sandy #frankenstorm http://t.co/mFEfmCMk
#
# The language guesses were: {'da': 2, 'so': 1, 'fi': 1, 'pl': 1, 'tl': 1, 'ca': 1, 'en': 3, 'af': 2}
# I predicted the language: en
#
# Returning the values: {'frankenstorm', 'today', 'forget', 'taken', 'sandy', 'guard', 'tomb', 'unknown', 'hurricane', 'soldier'} en
# the old value of the row is:  {'frankenstorm', 'today', 'forget', 'taken', 'sandy', 'guard', 'tomb', 'unknown', 'hurricane', 'soldier'}
# the new value of the row is:  {'frankenstorm', 'today', 'forget', 'taken', 'sandy', 'guard', 'tomb', 'unknown', 'hurricane', 'soldier'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 24 ----
#
#
# Going to tokenize the tweet: “@DarcyPhilip #new #york #hurricane #sandy http://t.co/z82Y0Kah” Bruh
# The original tweet was: “@DarcyPhilip #new #york #hurricane #sandy http://t.co/z82Y0Kah” Bruh
#
# The language guesses were: {'tr': 1, 'tl': 1, 'cs': 1, 'cy': 1, 'en': 1}
# I predicted the language: tr
#
# Returning the values: {'york', 'sandy', 'bruh', 'new', 'hurricane'} tr
# the old value of the row is:  {'york', 'sandy', 'bruh', 'new', 'hurricane'}
# the new value of the row is:  {'york', 'sandy', 'bruh', 'new', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 25 ----
#
#
# Going to tokenize the tweet: New York "attacked" by Sandy.  #NewYork #statueofliberty #hurricane #Sandy #dark #attack #sky #picoftheday # http://t.co/6PSNTCj9
# The original tweet was: New York "attacked" by Sandy.  #NewYork #statueofliberty #hurricane #Sandy #dark #attack #sky #picoftheday # http://t.co/6PSNTCj9
#
# The language guesses were: {'en': 3, 'tr': 1, 'sv': 2, 'tl': 1, 'id': 1, 'cy': 3, 'sk': 1}
# I predicted the language: en
#
# Returning the values: {'picoftheday', 'york', 'attacked', 'sandy', 'dark', 'attack', 'newyork', 'statueofliberty', 'new', 'sky', 'hurricane'} en
# the old value of the row is:  {'picoftheday', 'york', 'attacked', 'sandy', 'dark', 'attack', 'newyork', 'statueofliberty', 'new', 'sky', 'hurricane'}
# the new value of the row is:  {'picoftheday', 'york', 'attacked', 'sandy', 'dark', 'attack', 'newyork', 'statueofliberty', 'new', 'sky', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 26 ----
#
#
# Going to tokenize the tweet: This is sooo cute! #puupy #dog #hurricane #sandy #cute #adorable #flood #trees #golden #retriever #classic ☺ http://t.co/7nXoqVIY
# The original tweet was: This is sooo cute! #puupy #dog #hurricane #sandy #cute #adorable #flood #trees #golden #retriever #classic ☺ http://t.co/7nXoqVIY
#
# The language guesses were: {'cy': 3, 'fi': 1, 'es': 1, 'da': 1, 'tl': 1, 'ro': 1, 'en': 2, 'so': 1, 'af': 2, 'it': 1}
# I predicted the language: cy
#
# Returning the values: {'dog', 'puupy', 'adorable', 'retriever', 'sandy', 'cute', 'this', 'flood', 'sooo', 'golden', 'trees', 'classic', 'hurricane', 'is'} cy
# the old value of the row is:  {'dog', 'puupy', 'adorable', 'retriever', 'sandy', 'cute', 'this', 'flood', 'sooo', 'golden', 'trees', 'classic', 'hurricane', 'is'}
# the new value of the row is:  {'dog', 'puupy', 'adorable', 'retriever', 'sandy', 'cute', 'this', 'flood', 'sooo', 'golden', 'trees', 'classic', 'hurricane', 'is'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 27 ----
#
#
# Going to tokenize the tweet: empty streets #nyc #hurricane #sandy http://t.co/Uro00bM7
# The original tweet was: empty streets #nyc #hurricane #sandy http://t.co/Uro00bM7
#
# The language guesses were: {'tl': 1, 'pl': 1, 'af': 1, 'fr': 1, 'en': 1}
# I predicted the language: tl
#
# Returning the values: {'sandy', 'nyc', 'streets', 'empty', 'hurricane'} tl
# the old value of the row is:  {'sandy', 'nyc', 'streets', 'empty', 'hurricane'}
# the new value of the row is:  {'sandy', 'nyc', 'streets', 'empty', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 28 ----
#
#
# Going to tokenize the tweet: Shark. #Sandy #JerseyIThink #Hurricane #NYC #SomethingIsntRight #Animals #Shark #NaturalDisasterOrNot http://t.co/rylmIz5H
# The original tweet was: Shark. #Sandy #JerseyIThink #Hurricane #NYC #SomethingIsntRight #Animals #Shark #NaturalDisasterOrNot http://t.co/rylmIz5H
#
# The language guesses were: {'en': 2, 'et': 1, 'so': 1, 'tl': 1, 'pt': 1, 'pl': 1, 'sq': 1}
# I predicted the language: en
#
# Returning the values: {'somethingisntright', 'animals', 'shark', 'sandy', 'naturaldisasterornot', 'nyc', 'hurricane', 'jerseyithink'} en
# the old value of the row is:  {'somethingisntright', 'animals', 'shark', 'sandy', 'naturaldisasterornot', 'nyc', 'hurricane', 'jerseyithink'}
# the new value of the row is:  {'somethingisntright', 'animals', 'shark', 'sandy', 'naturaldisasterornot', 'nyc', 'hurricane', 'jerseyithink'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 29 ----
#
#
# Going to tokenize the tweet: Craziest picture ever #hurricane http://t.co/KaF8zQPE
# The original tweet was: Craziest picture ever #hurricane http://t.co/KaF8zQPE
#
# The language guesses were: {'it': 1, 'ro': 1, 'da': 1, 'en': 1}
# I predicted the language: it
#
# Returning the values: {'craziest', 'picture', 'ever', 'hurricane'} it
# the old value of the row is:  {'craziest', 'picture', 'ever', 'hurricane'}
# the new value of the row is:  {'craziest', 'picture', 'ever', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 30 ----
#
#
# Going to tokenize the tweet: #hurricane #sandy #WOW #NYC http://t.co/Gs7YMXXC
# The original tweet was: #hurricane #sandy #WOW #NYC http://t.co/Gs7YMXXC
#
# The language guesses were: {'pl': 2, 'tl': 1, 'en': 1}
# I predicted the language: pl
#
# Returning the values: {'nyc', 'sandy', 'wow', 'hurricane'} pl
# the old value of the row is:  {'nyc', 'sandy', 'wow', 'hurricane'}
# the new value of the row is:  {'nyc', 'sandy', 'wow', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 31 ----
#
#
# Going to tokenize the tweet: So New York is getting a little rain... #Hurricane #Sandy http://t.co/frWrVIss
# The original tweet was: So New York is getting a little rain... #Hurricane #Sandy http://t.co/frWrVIss
#
# The language guesses were: {'sv': 2, 'tr': 1, 'tl': 2, 'et': 1, 'cy': 1, 'lt': 1, 'en': 1, 'af': 1}
# I predicted the language: sv
#
# Returning the values: {'so', 'york', 'sandy', 'a', 'getting', 'little', 'new', 'rain', 'hurricane', 'is'} sv
# the old value of the row is:  {'so', 'york', 'sandy', 'a', 'getting', 'little', 'new', 'rain', 'hurricane', 'is'}
# the new value of the row is:  {'so', 'york', 'sandy', 'a', 'getting', 'little', 'new', 'rain', 'hurricane', 'is'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 32 ----
#
#
# Going to tokenize the tweet: The Tomb of the Unknown #Marines never take the #DayOff #Respect #NoDaysOff #Hurricane #Sandy #Superstorm http://t.co/sxsoJER6
# The original tweet was: The Tomb of the Unknown #Marines never take the #DayOff #Respect #NoDaysOff #Hurricane #Sandy #Superstorm http://t.co/sxsoJER6
#
# The language guesses were: {'so': 1, 'es': 1, 'id': 1, 'cy': 1, 'ro': 1, 'tl': 1, 'en': 5, 'hu': 1, 'fi': 1}
# I predicted the language: en
#
# Returning the values: {'dayoff', 'respect', 'marines', 'superstorm', 'nodaysoff', 'sandy', 'tomb', 'unknown', 'never', 'take', 'hurricane'} en
# the old value of the row is:  {'dayoff', 'respect', 'marines', 'superstorm', 'nodaysoff', 'sandy', 'tomb', 'unknown', 'never', 'take', 'hurricane'}
# the new value of the row is:  {'dayoff', 'respect', 'marines', 'superstorm', 'nodaysoff', 'sandy', 'tomb', 'unknown', 'never', 'take', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 33 ----
#
#
# Going to tokenize the tweet: Lord have mercy on their souls #Hurricane #Sandy #NewYork #RIP http://t.co/MYJpbl11
# The original tweet was: Lord have mercy on their souls #Hurricane #Sandy #NewYork #RIP http://t.co/MYJpbl11
#
# The language guesses were: {'es': 1, 'en': 2, 'hr': 1, 'cy': 2, 'tl': 1, 'no': 1, 'fr': 1, 'fi': 1}
# I predicted the language: en
#
# Returning the values: {'lord', 'rip', 'sandy', 'mercy', 'souls', 'newyork', 'hurricane'} en
# the old value of the row is:  {'lord', 'rip', 'sandy', 'mercy', 'souls', 'newyork', 'hurricane'}
# the new value of the row is:  {'lord', 'rip', 'sandy', 'mercy', 'souls', 'newyork', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 34 ----
#
#
# Going to tokenize the tweet: Look at this amazing pic taken today of #sandy #NYC #NewYorkCity #LadyLiberty #Hurricane #Amazing #Weather http://t.co/H4v7NbnI
# The original tweet was: Look at this amazing pic taken today of #sandy #NYC #NewYorkCity #LadyLiberty #Hurricane #Amazing #Weather http://t.co/H4v7NbnI
#
# The language guesses were: {'en': 4, 'sw': 1, 'so': 1, 'cy': 1, 'fi': 1, 'tl': 2, 'pl': 2, 'it': 1, 'et': 1}
# I predicted the language: en
#
# Returning the values: {'weather', 'amazing', 'ladyliberty', 'today', 'taken', 'sandy', 'newyorkcity', 'pic', 'nyc', 'look', 'hurricane'} en
# the old value of the row is:  {'weather', 'amazing', 'ladyliberty', 'today', 'taken', 'sandy', 'newyorkcity', 'pic', 'nyc', 'look', 'hurricane'}
# the new value of the row is:  {'weather', 'amazing', 'ladyliberty', 'today', 'taken', 'sandy', 'newyorkcity', 'pic', 'nyc', 'look', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 35 ----
#
#
# Going to tokenize the tweet: Mans best friend #love #hurricane #sandy #dog http://t.co/rJPcUYUn
# The original tweet was: Mans best friend #love #hurricane #sandy #dog http://t.co/rJPcUYUn
#
# The language guesses were: {'pt': 1, 'sl': 1, 'af': 1, 'tl': 2, 'da': 1, 'en': 1}
# I predicted the language: tl
#
# Returning the values: {'dog', 'love', 'best', 'sandy', 'mans', 'friend', 'hurricane'} tl
# the old value of the row is:  {'dog', 'love', 'best', 'sandy', 'mans', 'friend', 'hurricane'}
# the new value of the row is:  {'dog', 'love', 'best', 'sandy', 'mans', 'friend', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 36 ----
#
#
# Going to tokenize the tweet: #hurricane http://t.co/0ifMPBuq
# The original tweet was: #hurricane http://t.co/0ifMPBuq
#
# The language guesses were: {'en': 1}
# I predicted the language: en
#
# Returning the values: {'hurricane'} en
# the old value of the row is:  {'hurricane'}
# the new value of the row is:  {'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 37 ----
#
#
# Going to tokenize the tweet: Terrifying. #NY #hurricane #sandy #statueofliberty http://t.co/MSduqf2r
# The original tweet was: Terrifying. #NY #hurricane #sandy #statueofliberty http://t.co/MSduqf2r
#
# The language guesses were: {'tl': 1, 'no': 1, 'en': 2, 'sw': 1}
# I predicted the language: en
#
# Returning the values: {'sandy', 'terrifying', 'statueofliberty', 'ny', 'hurricane'} en
# the old value of the row is:  {'sandy', 'terrifying', 'statueofliberty', 'ny', 'hurricane'}
# the new value of the row is:  {'sandy', 'terrifying', 'statueofliberty', 'ny', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 38 ----
#
#
# Going to tokenize the tweet: #hurricane #sandy lookin like a bag of money http://t.co/lIWWuj6U
# The original tweet was: #hurricane #sandy lookin like a bag of money http://t.co/lIWWuj6U
#
# The language guesses were: {'et': 2, 'tl': 3, 'en': 3}
# I predicted the language: tl
#
# Returning the values: {'lookin', 'bag', 'sandy', 'a', 'like', 'of', 'hurricane', 'money'} tl
# the old value of the row is:  {'lookin', 'bag', 'sandy', 'a', 'like', 'of', 'hurricane', 'money'}
# the new value of the row is:  {'lookin', 'bag', 'sandy', 'a', 'like', 'of', 'hurricane', 'money'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 39 ----
#
#
# Going to tokenize the tweet: Crazy shot of #Hurricane #Sandy http://t.co/EQRFTgbD
# The original tweet was: Crazy shot of #Hurricane #Sandy http://t.co/EQRFTgbD
#
# The language guesses were: {'pl': 1, 'tl': 1, 'sq': 1, 'en': 2}
# I predicted the language: en
#
# Returning the values: {'sandy', 'shot', 'hurricane', 'crazy'} en
# the old value of the row is:  {'sandy', 'shot', 'hurricane', 'crazy'}
# the new value of the row is:  {'sandy', 'shot', 'hurricane', 'crazy'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 40 ----
#
#
# Going to tokenize the tweet: wow! #hurricane #Sandy over lady liberty  http://t.co/UbNMPbru via @TwitPic
# The original tweet was: wow! #hurricane #Sandy over lady liberty  http://t.co/UbNMPbru via @TwitPic
#
# The language guesses were: {'tl': 1, 'lt': 1, 'en': 2, 'no': 1, 'pl': 1, 'so': 1}
# I predicted the language: en
#
# Returning the values: {'sandy', 'via', 'wow', 'lady', 'liberty', 'hurricane'} en
# the old value of the row is:  {'sandy', 'via', 'wow', 'lady', 'liberty', 'hurricane'}
# the new value of the row is:  {'sandy', 'via', 'wow', 'lady', 'liberty', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 41 ----
#
#
# Going to tokenize the tweet: UMMMM😳 #shark #hurricane #nj WOAHH http://t.co/ach2BzUW
# The original tweet was: UMMMM😳 #shark #hurricane #nj WOAHH http://t.co/ach2BzUW
#
# The language guesses were: {'so': 1, 'pt': 1, 'pl': 1, 'sq': 1, 'en': 1}
# I predicted the language: so
#
# Returning the values: {'shark', 'ummm', 'woahh', 'nj', 'hurricane'} so
# the old value of the row is:  {'shark', 'ummm', 'woahh', 'nj', 'hurricane'}
# the new value of the row is:  {'shark', 'ummm', 'woahh', 'nj', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 42 ----
#
#
# Going to tokenize the tweet: #amazing #photography #nature #hurricane #sandy #clouds http://t.co/04kgQRRZ
# The original tweet was: #amazing #photography #nature #hurricane #sandy #clouds http://t.co/04kgQRRZ
#
# The language guesses were: {'en': 2, 'sw': 1, 'tl': 2, 'ca': 1}
# I predicted the language: en
#
# Returning the values: {'photography', 'amazing', 'nature', 'clouds', 'sandy', 'hurricane'} en
# the old value of the row is:  {'photography', 'amazing', 'nature', 'clouds', 'sandy', 'hurricane'}
# the new value of the row is:  {'photography', 'amazing', 'nature', 'clouds', 'sandy', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 43 ----
#
#
# Going to tokenize the tweet: So...that's a shark swimming in someone's front yard in NJ. #Sandy #shark #landshark #hurricane #fishing #be http://t.co/Vy7NOhKp
# The original tweet was: So...that's a shark swimming in someone's front yard in NJ. #Sandy #shark #landshark #hurricane #fishing #be http://t.co/Vy7NOhKp
#
# The language guesses were: {'id': 1, 'sv': 1, 'so': 2, 'en': 3, 'tl': 3, 'af': 1, 'tr': 1, 'sq': 1}
# I predicted the language: en
#
# Returning the values: {'shark', 'fishing', 'sandy', 'front', 'yard', 'swimming', 'nj', 'hurricane', 'landshark'} en
# the old value of the row is:  {'shark', 'fishing', 'sandy', 'front', 'yard', 'swimming', 'nj', 'hurricane', 'landshark'}
# the new value of the row is:  {'shark', 'fishing', 'sandy', 'front', 'yard', 'swimming', 'nj', 'hurricane', 'landshark'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 44 ----
#
#
# Going to tokenize the tweet: uh #hurricane #sandy #wind #blowing #cloudy #water #### # http://t.co/OVPam68k
# The original tweet was: uh #hurricane #sandy #wind #blowing #cloudy #water #### # http://t.co/OVPam68k
#
# The language guesses were: {'sw': 1, 'tl': 1, 'af': 1, 'en': 2, 'cy': 1, 'pl': 1}
# I predicted the language: en
#
# Returning the values: {'uh', 'water', 'sandy', 'blowing', 'cloudy', 'hurricane', 'wind'} en
# the old value of the row is:  {'uh', 'water', 'sandy', 'blowing', 'cloudy', 'hurricane', 'wind'}
# the new value of the row is:  {'uh', 'water', 'sandy', 'blowing', 'cloudy', 'hurricane', 'wind'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 45 ----
#
#
# Going to tokenize the tweet: #hurricane #sandy #NY #NewYork http://t.co/EtktgqAt
# The original tweet was: #hurricane #sandy #NY #NewYork http://t.co/EtktgqAt
#
# The language guesses were: {'cy': 1, 'tl': 1, 'sw': 1, 'en': 1}
# I predicted the language: cy
#
# Returning the values: {'newyork', 'sandy', 'ny', 'hurricane'} cy
# the old value of the row is:  {'newyork', 'sandy', 'ny', 'hurricane'}
# the new value of the row is:  {'newyork', 'sandy', 'ny', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 46 ----
#
#
# Going to tokenize the tweet: Damnnn dis joint look like those end of the world movies #repost #rp #hurricane #sandy http://t.co/6lzyWDj1
# The original tweet was: Damnnn dis joint look like those end of the world movies #repost #rp #hurricane #sandy http://t.co/6lzyWDj1
#
# The language guesses were: {'id': 1, 'sl': 1, 'en': 4, 'sk': 1, 'tl': 1, 'af': 2, 'et': 2, 'da': 1, 'fi': 1, 'lt': 1}
# I predicted the language: en
#
# Returning the values: {'damnnn', 'repost', 'movies', 'sandy', 'dis', 'world', 'look', 'like', 'end', 'joint', 'hurricane', 'rp'} en
# the old value of the row is:  {'damnnn', 'repost', 'movies', 'sandy', 'dis', 'world', 'look', 'like', 'end', 'joint', 'hurricane', 'rp'}
# the new value of the row is:  {'damnnn', 'repost', 'movies', 'sandy', 'dis', 'world', 'look', 'like', 'end', 'joint', 'hurricane', 'rp'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 47 ----
#
#
# Going to tokenize the tweet: #hurricane #sandy #NY #newyork #america #usa #sky #tube #instago #instaboy #instahub #i#instagood #instagram http://t.co/MMqpZxE8
# The original tweet was: #hurricane #sandy #NY #newyork #america #usa #sky #tube #instago #instaboy #instahub #i#instagood #instagram http://t.co/MMqpZxE8
#
# The language guesses were: {'ca': 1, 'tl': 2, 'af': 2, 'sv': 1, 'id': 1, 'cy': 1, 'et': 1, 'fi': 1, 'en': 2, 'sw': 1, 'sk': 1}
# I predicted the language: tl
#
# Returning the values: {'america', 'sandy', 'i', 'instagram', 'instahub', 'instagood', 'newyork', 'tube', 'usa', 'instaboy', 'ny', 'sky', 'hurricane', 'instago'} tl
# the old value of the row is:  {'america', 'sandy', 'i', 'instagram', 'instahub', 'instagood', 'newyork', 'tube', 'usa', 'instaboy', 'ny', 'sky', 'hurricane', 'instago'}
# the new value of the row is:  {'america', 'sandy', 'i', 'instagram', 'instahub', 'instagood', 'newyork', 'tube', 'usa', 'instaboy', 'ny', 'sky', 'hurricane', 'instago'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 48 ----
#
#
# Going to tokenize the tweet: #NewYork #Crazy #Statue #Liberty #Hurricane #Today #Nature #2012 http://t.co/wi5DuGPH
# The original tweet was: #NewYork #Crazy #Statue #Liberty #Hurricane #Today #Nature #2012 http://t.co/wi5DuGPH
#
# The language guesses were: {'so': 1, 'tl': 1, 'pl': 1, 'en': 2, 'cy': 1, 'it': 1}
# I predicted the language: en
#
# Returning the values: {'today', 'nature', 'crazy', 'newyork', 'statue', 'liberty', 'hurricane'} en
# the old value of the row is:  {'today', 'nature', 'crazy', 'newyork', 'statue', 'liberty', 'hurricane'}
# the new value of the row is:  {'today', 'nature', 'crazy', 'newyork', 'statue', 'liberty', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 49 ----
#
#
# Going to tokenize the tweet: 😱 #shark #nyc #streets #sandy #hurricane http://t.co/NcudDwxJ
# The original tweet was: 😱 #shark #nyc #streets #sandy #hurricane http://t.co/NcudDwxJ
#
# The language guesses were: {'so': 1, 'tl': 1, 'pl': 1, 'af': 1, 'en': 1}
# I predicted the language: so
#
# Returning the values: {'shark', 'sandy', 'nyc', 'streets', 'hurricane'} so
# the old value of the row is:  {'shark', 'sandy', 'nyc', 'streets', 'hurricane'}
# the new value of the row is:  {'shark', 'sandy', 'nyc', 'streets', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 50 ----
#
#
# Going to tokenize the tweet: A picture someone took of a shark swimming by their house when it got flooded 😱 \n#NewJersey #Hurricane #Sand http://t.co/OCXLWDFY
# The original tweet was: A picture someone took of a shark swimming by their house when it got flooded 😱 \n#NewJersey #Hurricane #Sand http://t.co/OCXLWDFY
#
# The language guesses were: {'en': 5, 'so': 1, 'cy': 2, 'tl': 5, 'hr': 1, 'af': 2, 'ro': 1, 'no': 1}
# I predicted the language: en
#
# Returning the values: {'shark', 'house', 'flooded', 'newjersey', 'got', 'sand', 'took', 'swimming', 'picture', 'someone', 'hurricane', 'n'} en
# the old value of the row is:  {'shark', 'house', 'flooded', 'newjersey', 'got', 'sand', 'took', 'swimming', 'picture', 'someone', 'hurricane', 'n'}
# the new value of the row is:  {'shark', 'house', 'flooded', 'newjersey', 'got', 'sand', 'took', 'swimming', 'picture', 'someone', 'hurricane', 'n'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 51 ----
#
#
# Going to tokenize the tweet: I hope the East Coast is doing well in those times. Thoughts are with y'all xo #hurricane #sandy #eastcoast http://t.co/9nKj08t8
# The original tweet was: I hope the East Coast is doing well in those times. Thoughts are with y'all xo #hurricane #sandy #eastcoast http://t.co/9nKj08t8
#
# The language guesses were: {'sq': 1, 'so': 1, 'cy': 1, 'en': 8, 'af': 3, 'tl': 1, 'pt': 1, 'ro': 2}
# I predicted the language: en
#
# Returning the values: {'times', 'xo', 'well', 'sandy', 'east', 'eastcoast', 'hope', 'coast', 'thoughts', 'hurricane'} en
# the old value of the row is:  {'times', 'xo', 'well', 'sandy', 'east', 'eastcoast', 'hope', 'coast', 'thoughts', 'hurricane'}
# the new value of the row is:  {'times', 'xo', 'well', 'sandy', 'east', 'eastcoast', 'hope', 'coast', 'thoughts', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 52 ----
#
#
# Going to tokenize the tweet: It's gettin real out in this bitch.. #repost #sandy #hurricane #bitchimashark http://t.co/s3hfZXTY
# The original tweet was: It's gettin real out in this bitch.. #repost #sandy #hurricane #bitchimashark http://t.co/s3hfZXTY
#
# The language guesses were: {'ro': 1, 'sl': 1, 'sv': 1, 'tl': 1, 'af': 1, 'en': 2, 'fr': 1, 'so': 1, 'vi': 1}
# I predicted the language: en
#
# Returning the values: {'real', 'repost', 'gettin', 'sandy', 'bitchimashark', 'bitch', 'hurricane'} en
# the old value of the row is:  {'real', 'repost', 'gettin', 'sandy', 'bitchimashark', 'bitch', 'hurricane'}
# the new value of the row is:  {'real', 'repost', 'gettin', 'sandy', 'bitchimashark', 'bitch', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 53 ----
#
#
# Going to tokenize the tweet: #2012 #statueofliberty #NYC #world #ends #hurricane #sandy 😳😳 http://t.co/qYPMgIrH
# The original tweet was: #2012 #statueofliberty #NYC #world #ends #hurricane #sandy 😳😳 http://t.co/qYPMgIrH
#
# The language guesses were: {'tl': 1, 'af': 1, 'pl': 1, 'en': 2, 'da': 1}
# I predicted the language: en
#
# Returning the values: {'sandy', 'world', 'nyc', 'statueofliberty', 'hurricane', 'ends'} en
# the old value of the row is:  {'sandy', 'world', 'nyc', 'statueofliberty', 'hurricane', 'ends'}
# the new value of the row is:  {'sandy', 'world', 'nyc', 'statueofliberty', 'hurricane', 'ends'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 54 ----
#
#
# Going to tokenize the tweet: #NY #hurricane #cool http://t.co/XbXap7JQ
# The original tweet was: #NY #hurricane #cool http://t.co/XbXap7JQ
#
# The language guesses were: {'en': 2, 'sw': 1}
# I predicted the language: en
#
# Returning the values: {'cool', 'ny', 'hurricane'} en
# the old value of the row is:  {'cool', 'ny', 'hurricane'}
# the new value of the row is:  {'cool', 'ny', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 55 ----
#
#
# Going to tokenize the tweet: The Eye of The Storm... #Hurricane #Sandy http://t.co/0mMUrbZN
# The original tweet was: The Eye of The Storm... #Hurricane #Sandy http://t.co/0mMUrbZN
#
# The language guesses were: {'tl': 1, 'tr': 1, 'en': 3, 'sk': 1}
# I predicted the language: en
#
# Returning the values: {'eye', 'sandy', 'storm', 'hurricane'} en
# the old value of the row is:  {'eye', 'sandy', 'storm', 'hurricane'}
# the new value of the row is:  {'eye', 'sandy', 'storm', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 56 ----
#
#
# Going to tokenize the tweet: #timesquare #newyork #nyc #ghostcity #hurricane #sandy http://t.co/hsVUO6Fn
# The original tweet was: #timesquare #newyork #nyc #ghostcity #hurricane #sandy http://t.co/hsVUO6Fn
#
# The language guesses were: {'en': 2, 'tl': 1, 'sq': 1, 'pl': 1, 'cy': 1}
# I predicted the language: en
#
# Returning the values: {'ghostcity', 'sandy', 'timesquare', 'nyc', 'newyork', 'hurricane'} en
# the old value of the row is:  {'ghostcity', 'sandy', 'timesquare', 'nyc', 'newyork', 'hurricane'}
# the new value of the row is:  {'ghostcity', 'sandy', 'timesquare', 'nyc', 'newyork', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 57 ----
#
#
# Going to tokenize the tweet: #newyork #hurricane #sandy http://t.co/8wcCP9c5
# The original tweet was: #newyork #hurricane #sandy http://t.co/8wcCP9c5
#
# The language guesses were: {'tl': 1, 'cy': 1, 'en': 1}
# I predicted the language: tl
#
# Returning the values: {'sandy', 'newyork', 'hurricane'} tl
# the old value of the row is:  {'sandy', 'newyork', 'hurricane'}
# the new value of the row is:  {'sandy', 'newyork', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 58 ----
#
#
# Going to tokenize the tweet: Hope all my family and friends on the east coast stay safe!! #Hurricane #sandy #ilovecali #storm #clouds #ra http://t.co/dHjMlGrc
# The original tweet was: Hope all my family and friends on the east coast stay safe!! #Hurricane #sandy #ilovecali #storm #clouds #ra http://t.co/dHjMlGrc
#
# The language guesses were: {'en': 5, 'sk': 1, 'ca': 1, 'hr': 1, 'tl': 2, 'cy': 2, 'nl': 1, 'it': 1, 'sl': 1, 'ro': 1, 'da': 1, 'fi': 1}
# I predicted the language: en
#
# Returning the values: {'friends', 'clouds', 'ra', 'sandy', 'east', 'safe', 'stay', 'hope', 'ilovecali', 'coast', 'family', 'storm', 'hurricane'} en
# the old value of the row is:  {'friends', 'clouds', 'ra', 'sandy', 'east', 'safe', 'stay', 'hope', 'ilovecali', 'coast', 'family', 'storm', 'hurricane'}
# the new value of the row is:  {'friends', 'clouds', 'ra', 'sandy', 'east', 'safe', 'stay', 'hope', 'ilovecali', 'coast', 'family', 'storm', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 59 ----
#
#
# Going to tokenize the tweet: #hurricane http://t.co/RKNYPVU8
# The original tweet was: #hurricane http://t.co/RKNYPVU8
#
# The language guesses were: {'en': 1}
# I predicted the language: en
#
# Returning the values: {'hurricane'} en
# the old value of the row is:  {'hurricane'}
# the new value of the row is:  {'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 60 ----
#
#
# Going to tokenize the tweet: #Hurricane #Sandy #NYC 🌀☔🗽 http://t.co/gNLZiF29
# The original tweet was: #Hurricane #Sandy #NYC 🌀☔🗽 http://t.co/gNLZiF29
#
# The language guesses were: {'pl': 1, 'tl': 1, 'en': 1}
# I predicted the language: pl
#
# Returning the values: {'nyc', 'sandy', 'hurricane'} pl
# the old value of the row is:  {'nyc', 'sandy', 'hurricane'}
# the new value of the row is:  {'nyc', 'sandy', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 61 ----
#
#
# Going to tokenize the tweet: Still no place like it !!! RT @cruzr83: Eerie look in Manhattan. #sandy #nyc #weather #hurricane http://t.co/HKpOueN3
# The original tweet was: Still no place like it !!! RT @cruzr83: Eerie look in Manhattan. #sandy #nyc #weather #hurricane http://t.co/HKpOueN3
#
# The language guesses were: {'en': 2, 'sv': 1, 'es': 1, 'fr': 1, 'tl': 3, 'af': 1, 'pl': 1, 'et': 2, 'nl': 1, 'fi': 1}
# I predicted the language: tl
#
# Returning the values: {'weather', 'still', 'place', 'rt', 'sandy', 'in', 'nyc', 'look', 'like', 'eerie', 'it', 'no', 'manhattan', 'hurricane'} tl
# the old value of the row is:  {'weather', 'still', 'place', 'rt', 'sandy', 'in', 'nyc', 'look', 'like', 'eerie', 'it', 'no', 'manhattan', 'hurricane'}
# the new value of the row is:  {'weather', 'still', 'place', 'rt', 'sandy', 'in', 'nyc', 'look', 'like', 'eerie', 'it', 'no', 'manhattan', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 62 ----
#
#
# Going to tokenize the tweet: WTF! LaGuardia Airport! #JetBlue #Travel #Sandy #Hurricane http://t.co/rMnIn46u
# The original tweet was: WTF! LaGuardia Airport! #JetBlue #Travel #Sandy #Hurricane http://t.co/rMnIn46u
#
# The language guesses were: {'hr': 1, 'sl': 1, 'tl': 1, 'cy': 1, 'fr': 1, 'id': 1, 'en': 1}
# I predicted the language: hr
#
# Returning the values: {'jetblue', 'travel', 'sandy', 'wtf', 'airport', 'laguardia', 'hurricane'} hr
# the old value of the row is:  {'jetblue', 'travel', 'sandy', 'wtf', 'airport', 'laguardia', 'hurricane'}
# the new value of the row is:  {'jetblue', 'travel', 'sandy', 'wtf', 'airport', 'laguardia', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 63 ----
#
#
# Going to tokenize the tweet: #newyork I'm prayin for y'all #hurricane #sand #realimage #jesus 🙏 http://t.co/S5Daawe3
# The original tweet was: #newyork I'm prayin for y'all #hurricane #sand #realimage #jesus 🙏 http://t.co/S5Daawe3
#
# The language guesses were: {'tl': 1, 'cy': 1, 'hr': 1, 'da': 1, 'ro': 1, 'en': 1, 'tr': 1}
# I predicted the language: tl
#
# Returning the values: {'sand', 'newyork', 'jesus', 'for', 'realimage', 'hurricane', 'prayin'} tl
# the old value of the row is:  {'sand', 'newyork', 'jesus', 'for', 'realimage', 'hurricane', 'prayin'}
# the new value of the row is:  {'sand', 'newyork', 'jesus', 'for', 'realimage', 'hurricane', 'prayin'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 64 ----
#
#
# Going to tokenize the tweet: #Hurricane #Sandy #NYC 🌀☔🗽 http://t.co/gNLZiF29
# The original tweet was: #Hurricane #Sandy #NYC 🌀☔🗽 http://t.co/gNLZiF29
#
# The language guesses were: {'pl': 1, 'tl': 1, 'en': 1}
# I predicted the language: pl
#
# Returning the values: {'nyc', 'sandy', 'hurricane'} pl
# the old value of the row is:  {'nyc', 'sandy', 'hurricane'}
# the new value of the row is:  {'nyc', 'sandy', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 65 ----
#
#
# Going to tokenize the tweet: Scary!!!! #newyork #hurricane #sandy #newyorkcity #ny #fuckingrun http://t.co/TyKfkMAj
# The original tweet was: Scary!!!! #newyork #hurricane #sandy #newyorkcity #ny #fuckingrun http://t.co/TyKfkMAj
#
# The language guesses were: {'tl': 1, 'pl': 1, 'en': 2, 'cy': 1, 'sw': 1, 'sv': 1}
# I predicted the language: en
#
# Returning the values: {'sandy', 'newyorkcity', 'scary', 'newyork', 'ny', 'hurricane', 'fuckingrun'} en
# the old value of the row is:  {'sandy', 'newyorkcity', 'scary', 'newyork', 'ny', 'hurricane', 'fuckingrun'}
# the new value of the row is:  {'sandy', 'newyorkcity', 'scary', 'newyork', 'ny', 'hurricane', 'fuckingrun'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 66 ----
#
#
# Going to tokenize the tweet: Que Deus proteja o Soho, a All Saints e a XL ! #Sandy #FuracãoSandy  #Hurricane #NY #EUA http://t.co/uEXducey
# ...
# the old value of the row is:  {'be', 'here', 'york', 'sandy', 'rt', 'in', 'out', 'safe', 'new'}
# the new value of the row is:  {'be', 'here', 'york', 'sandy', 'rt', 'in', 'out', 'safe', 'new'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2160 ----
#
#
# Going to tokenize the tweet: Hurricane Sandy, my prayers are going out to all of you guys in the path off the hurricane! http://t.co/LyJ1tOkU
# The original tweet was: Hurricane Sandy, my prayers are going out to all of you guys in the path off the hurricane! http://t.co/LyJ1tOkU
#
# The language guesses were: {'en': 6, 'tl': 3, 'af': 1, 'cy': 1, 'fr': 1, 'sw': 1, 'ro': 1, 'it': 1, 'so': 1}
# I predicted the language: en
#
# Returning the values: {'going', 'prayers', 'sandy', 'path', 'guys', 'hurricane'} en
# the old value of the row is:  {'going', 'prayers', 'sandy', 'path', 'guys', 'hurricane'}
# the new value of the row is:  {'going', 'prayers', 'sandy', 'path', 'guys', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2161 ----
#
#
# Going to tokenize the tweet: attend avec impatience le photo-reportage de The BigPicture à propos de Sandy parce que là ça part en sucette   http://t.co/f0x9S66p
# The original tweet was: attend avec impatience le photo-reportage de The BigPicture à propos de Sandy parce que là ça part en sucette   http://t.co/f0x9S66p
#
# The language guesses were: {'vi': 1, 'it': 2, 'sv': 2, 'es': 1, 'ro': 1, 'fr': 4, 'ca': 1, 'tl': 1, 'tr': 1, 'nl': 1, 'cs': 1, 'en': 1}
# I predicted the language: fr
#
# Returning the values: {'là', 'bigpicture', 'impatience', 'attend', 'parce', 'ça', 'sandy', 'sucette', 'propos', 'the', 'part'} fr
# the old value of the row is:  {'là', 'bigpicture', 'impatience', 'attend', 'parce', 'ça', 'sandy', 'sucette', 'propos', 'the', 'part'}
# the new value of the row is:  {'là', 'bigpicture', 'impatience', 'attend', 'parce', 'ça', 'sandy', 'sucette', 'propos', 'the', 'part'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2162 ----
#
#
# Going to tokenize the tweet: Took this from a friend, a guy found a shark in his front yard after sandy! #crazystroms #sandyaftermath #iw http://t.co/Bzv30z9F
# The original tweet was: Took this from a friend, a guy found a shark in his front yard after sandy! #crazystroms #sandyaftermath #iw http://t.co/Bzv30z9F
#
# The language guesses were: {'so': 2, 'pl': 1, 'sw': 1, 'tl': 2, 'en': 6, 'af': 2, 'tr': 1, 'da': 2}
# I predicted the language: en
#
# Returning the values: {'guy', 'shark', 'iw', 'sandy', 'front', 'yard', 'took', 'friend', 'sandyaftermath', 'found', 'crazystroms'} en
# the old value of the row is:  {'guy', 'shark', 'iw', 'sandy', 'front', 'yard', 'took', 'friend', 'sandyaftermath', 'found', 'crazystroms'}
# the new value of the row is:  {'guy', 'shark', 'iw', 'sandy', 'front', 'yard', 'took', 'friend', 'sandyaftermath', 'found', 'crazystroms'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2163 ----
#
#
# Going to tokenize the tweet: Even in the midsts of Hurricane Sandy our troops stand guard! #Proud #SupportOurTroops #MyBrotherIsAMarine http://t.co/0oLf1drr
# The original tweet was: Even in the midsts of Hurricane Sandy our troops stand guard! #Proud #SupportOurTroops #MyBrotherIsAMarine http://t.co/0oLf1drr
#
# The language guesses were: {'et': 1, 'cs': 1, 'fr': 2, 'en': 4, 'tl': 1, 'sv': 1, 'af': 2, 'ca': 1, 'nl': 1}
# I predicted the language: en
#
# Returning the values: {'midsts', 'proud', 'stand', 'sandy', 'guard', 'supportourtroops', 'troops', 'even', 'mybrotherisamarine', 'hurricane'} en
# the old value of the row is:  {'midsts', 'proud', 'stand', 'sandy', 'guard', 'supportourtroops', 'troops', 'even', 'mybrotherisamarine', 'hurricane'}
# the new value of the row is:  {'midsts', 'proud', 'stand', 'sandy', 'guard', 'supportourtroops', 'troops', 'even', 'mybrotherisamarine', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2164 ----
#
#
# Going to tokenize the tweet: This is NOT photoshopped. Sandy is creeping me out. Saying a prayer for all my friends on the East Coast. Ha http://t.co/ygNuNWhY
# The original tweet was: This is NOT photoshopped. Sandy is creeping me out. Saying a prayer for all my friends on the East Coast. Ha http://t.co/ygNuNWhY
#
# The language guesses were: {'tl': 3, 'en': 5, 'lv': 1, 'tr': 1, 'da': 2, 'ro': 1, 'fi': 1, 'cy': 1, 'fr': 1, 'so': 1, 'it': 1, 'id': 1, 'af': 1}
# I predicted the language: en
#
# Returning the values: {'sandy', 'saying', 'east', 'creeping', 'ha', 'prayer', 'photoshopped', 'coast', 'friends'} en
# the old value of the row is:  {'sandy', 'saying', 'east', 'creeping', 'ha', 'prayer', 'photoshopped', 'coast', 'friends'}
# the new value of the row is:  {'sandy', 'saying', 'east', 'creeping', 'ha', 'prayer', 'photoshopped', 'coast', 'friends'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2165 ----
#
#
# Going to tokenize the tweet: https://t.co/5nSGIteD oh shit door orkaan sandy zemmen er gewoon haaien in de stad
# The original tweet was: https://t.co/5nSGIteD oh shit door orkaan sandy zemmen er gewoon haaien in de stad
#
# The language guesses were: {'da': 1, 'fi': 2, 'es': 1, 'af': 2, 'tl': 1, 'sv': 1, 'nl': 1, 'sq': 1, 'so': 1, 'de': 1}
# I predicted the language: fi
#
# Returning the values: {'er', 'haaien', 'de', 'gewoon', 'sandy', 'stad', 'door', 'shit', 'orkaan', 'in', 'zemmen', 'oh'} fi
# the old value of the row is:  {'er', 'haaien', 'de', 'gewoon', 'sandy', 'stad', 'door', 'shit', 'orkaan', 'in', 'zemmen', 'oh'}
# the new value of the row is:  {'er', 'haaien', 'de', 'gewoon', 'sandy', 'stad', 'door', 'shit', 'orkaan', 'in', 'zemmen', 'oh'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2166 ----
#
#
# Going to tokenize the tweet: In the first days of the storm .. Losses 'Sandy' killed 73 and the closure of the stock market and cut off e http://t.co/UJ1OzZcV
# The original tweet was: In the first days of the storm .. Losses 'Sandy' killed 73 and the closure of the stock market and cut off e http://t.co/UJ1OzZcV
#
# The language guesses were: {'en': 5, 'tl': 1, 'es': 2, 'af': 1, 'sv': 1, 'ro': 1, 'so': 1, 'no': 1, 'da': 1, 'fi': 1, 'sk': 1}
# I predicted the language: en
#
# Returning the values: {'storm', 'sandy', 'closure', 'first', 'days', 'market', 'killed', 'losses', 'cut', 'stock', 'e'} en
# the old value of the row is:  {'storm', 'sandy', 'closure', 'first', 'days', 'market', 'killed', 'losses', 'cut', 'stock', 'e'}
# the new value of the row is:  {'storm', 'sandy', 'closure', 'first', 'days', 'market', 'killed', 'losses', 'cut', 'stock', 'e'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2167 ----
#
#
# Going to tokenize the tweet: Sick pic of Sandy over the Big Apple... http://t.co/ly8tn8ME
# The original tweet was: Sick pic of Sandy over the Big Apple... http://t.co/ly8tn8ME
#
# The language guesses were: {'tl': 2, 'de': 1, 'fr': 1, 'it': 1, 'no': 1, 'en': 2}
# I predicted the language: tl
#
# Returning the values: {'sandy', 'sick', 'apple', 'big', 'pic', 'over', 'the', 'of'} tl
# the old value of the row is:  {'sandy', 'sick', 'apple', 'big', 'pic', 'over', 'the', 'of'}
# the new value of the row is:  {'sandy', 'sick', 'apple', 'big', 'pic', 'over', 'the', 'of'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2168 ----
#
#
# Going to tokenize the tweet: 'Good 'ol Sandy' Hang tight and stay dry my New York friends! "The sun will come out tomorrow!" #prayers http://t.co/A8i0Kycz
# The original tweet was: 'Good 'ol Sandy' Hang tight and stay dry my New York friends! "The sun will come out tomorrow!" #prayers http://t.co/A8i0Kycz
#
# The language guesses were: {'tl': 3, 'en': 5, 'sw': 1, 'cy': 3, 'tr': 1, 'fr': 1, 'fi': 1, 'ro': 1, 'pt': 1, 'so': 1, 'da': 1}
# I predicted the language: en
#
# Returning the values: {'hang', 'york', 'prayers', 'tight', 'sandy', 'come', 'dry', 'stay', 'ol', 'good', 'friends', 'new', 'tomorrow', 'sun'} en
# the old value of the row is:  {'hang', 'york', 'prayers', 'tight', 'sandy', 'come', 'dry', 'stay', 'ol', 'good', 'friends', 'new', 'tomorrow', 'sun'}
# the new value of the row is:  {'hang', 'york', 'prayers', 'tight', 'sandy', 'come', 'dry', 'stay', 'ol', 'good', 'friends', 'new', 'tomorrow', 'sun'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2169 ----
#
#
# Going to tokenize the tweet: since we all talking bout her...why not post of pic of how sandy looking in NY today 😨 http://t.co/XCoYtLbn
# The original tweet was: since we all talking bout her...why not post of pic of how sandy looking in NY today 😨 http://t.co/XCoYtLbn
#
# The language guesses were: {'it': 3, 'sw': 1, 'en': 3, 'so': 2, 'fi': 1, 'pl': 1, 'tl': 2, 'af': 1, 'nl': 1, 'sl': 1, 'lv': 1}
# I predicted the language: it
#
# Returning the values: {'since', 'today', 'why', 'talking', 'we', 'sandy', 'how', 'of', 'pic', 'her', 'bout', 'ny', 'looking', 'post', 'not'} it
# the old value of the row is:  {'since', 'today', 'why', 'talking', 'we', 'sandy', 'how', 'of', 'pic', 'her', 'bout', 'ny', 'looking', 'post', 'not'}
# the new value of the row is:  {'since', 'today', 'why', 'talking', 'we', 'sandy', 'how', 'of', 'pic', 'her', 'bout', 'ny', 'looking', 'post', 'not'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2170 ----
#
#
# Going to tokenize the tweet: “@ARSONALDAREBEL: So DIS WAT SANDY GOT DA SKY IN NYC LOOKIN LIKE. http://t.co/f94A5RN7” Looks EXACTLY like the scene in 2012
# The original tweet was: “@ARSONALDAREBEL: So DIS WAT SANDY GOT DA SKY IN NYC LOOKIN LIKE. http://t.co/f94A5RN7” Looks EXACTLY like the scene in 2012
#
# The language guesses were: {'sv': 1, 'et': 3, 'sw': 1, 'tl': 1, 'af': 2, 'hr': 1, 'en': 2, 'pl': 1, 'id': 1, 'it': 1, 'sk': 1}
# I predicted the language: et
#
# Returning the values: {'so', 'lookin', 'wat', 'sandy', 'dis', 'in', 'got', 'exactly', 'nyc', 'looks', 'da', 'like', 'scene', 'the', 'sky'} et
# the old value of the row is:  {'so', 'lookin', 'wat', 'sandy', 'dis', 'in', 'got', 'exactly', 'nyc', 'looks', 'da', 'like', 'scene', 'the', 'sky'}
# the new value of the row is:  {'so', 'lookin', 'wat', 'sandy', 'dis', 'in', 'got', 'exactly', 'nyc', 'looks', 'da', 'like', 'scene', 'the', 'sky'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2171 ----
#
#
# Going to tokenize the tweet: Today in DC, Sandy brings rain, but it comes with the territory.  Havin a tough day? Quit your whining! #hon http://t.co/8CSWVQ73
# The original tweet was: Today in DC, Sandy brings rain, but it comes with the territory.  Havin a tough day? Quit your whining! #hon http://t.co/8CSWVQ73
#
# The language guesses were: {'pt': 2, 'da': 1, 'id': 1, 'lt': 1, 'cy': 1, 'en': 5, 'so': 2, 'no': 1, 'tl': 3, 'tr': 1, 'af': 1, 'fr': 1}
# I predicted the language: en
#
# Returning the values: {'dc', 'hon', 'territory', 'whining', 'brings', 'today', 'havin', 'day', 'sandy', 'comes', 'tough', 'quit', 'rain'} en
# the old value of the row is:  {'dc', 'hon', 'territory', 'whining', 'brings', 'today', 'havin', 'day', 'sandy', 'comes', 'tough', 'quit', 'rain'}
# the new value of the row is:  {'dc', 'hon', 'territory', 'whining', 'brings', 'today', 'havin', 'day', 'sandy', 'comes', 'tough', 'quit', 'rain'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2172 ----
#
#
# Going to tokenize the tweet: sandy. the crane dangling is near my apt http://t.co/e5khJ3Hv
# The original tweet was: sandy. the crane dangling is near my apt http://t.co/e5khJ3Hv
#
# The language guesses were: {'lv': 1, 'tl': 2, 'cy': 1, 'it': 2, 'en': 1, 'af': 1}
# I predicted the language: tl
#
# Returning the values: {'apt', 'sandy', 'my', 'dangling', 'crane', 'near', 'the', 'is'} tl
# the old value of the row is:  {'apt', 'sandy', 'my', 'dangling', 'crane', 'near', 'the', 'is'}
# the new value of the row is:  {'apt', 'sandy', 'my', 'dangling', 'crane', 'near', 'the', 'is'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2173 ----
#
#
# Going to tokenize the tweet: Hurricane Sandy look like an aggrivated ex-wife in N.Y.C &amp; She bought to be in the D.M.V by 6pm . Fml http://t.co/dDmH0Fmy
# The original tweet was: Hurricane Sandy look like an aggrivated ex-wife in N.Y.C &amp; She bought to be in the D.M.V by 6pm . Fml http://t.co/dDmH0Fmy
#
# The language guesses were: {'sv': 1, 'sk': 1, 'lv': 1, 'tl': 3, 'pt': 1, 'it': 1, 'en': 4, 'et': 2, 'vi': 1, 'cy': 2, 'sq': 1, 'sw': 1, 'id': 1, 'af': 1}
# I predicted the language: en
#
# Returning the values: {'fml', 'aggrivated', 'sandy', 'v', 'look', 'c', '6pm', 'like', 'hurricane', 'n', 'bought'} en
# the old value of the row is:  {'fml', 'aggrivated', 'sandy', 'v', 'look', 'c', '6pm', 'like', 'hurricane', 'n', 'bought'}
# the new value of the row is:  {'fml', 'aggrivated', 'sandy', 'v', 'look', 'c', '6pm', 'like', 'hurricane', 'n', 'bought'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2174 ----
#
#
# Going to tokenize the tweet: Due to Sandy, there are sharks in the flooded streets of NYC. God help us all http://t.co/SckbrML4
# The original tweet was: Due to Sandy, there are sharks in the flooded streets of NYC. God help us all http://t.co/SckbrML4
#
# The language guesses were: {'en': 4, 'tl': 1, 'af': 2, 'cy': 2, 'fr': 1, 'pl': 1, 'hr': 1, 'ro': 1, 'nl': 1, 'it': 1, 'sq': 1}
# I predicted the language: en
#
# Returning the values: {'sandy', 'flooded', 'god', 'due', 'nyc', 'us', 'help', 'streets', 'sharks'} en
# the old value of the row is:  {'sandy', 'flooded', 'god', 'due', 'nyc', 'us', 'help', 'streets', 'sharks'}
# the new value of the row is:  {'sandy', 'flooded', 'god', 'due', 'nyc', 'us', 'help', 'streets', 'sharks'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2175 ----
#
#
# Going to tokenize the tweet: The power of nature. Photo from Sandy update Facebook page. @ NYC♥ http://t.co/B3q2JfXa
# The original tweet was: The power of nature. Photo from Sandy update Facebook page. @ NYC♥ http://t.co/B3q2JfXa
#
# The language guesses were: {'tl': 3, 'sl': 1, 'en': 4, 'vi': 1, 'pl': 2}
# I predicted the language: en
#
# Returning the values: {'nature', 'update', 'sandy', 'page', 'photo', 'nyc', 'facebook', 'power'} en
# the old value of the row is:  {'nature', 'update', 'sandy', 'page', 'photo', 'nyc', 'facebook', 'power'}
# the new value of the row is:  {'nature', 'update', 'sandy', 'page', 'photo', 'nyc', 'facebook', 'power'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2176 ----
#
#
# Going to tokenize the tweet: Damn, look what Sandy is bringing to the land yo :( http://t.co/sgbZrwh5
# The original tweet was: Damn, look what Sandy is bringing to the land yo :( http://t.co/sgbZrwh5
#
# The language guesses were: {'en': 3, 'tl': 2, 'es': 1, 'et': 1, 'id': 1, 'tr': 1, 'af': 1}
# I predicted the language: en
#
# Returning the values: {'sandy', 'land', 'look', 'damn', 'yo', 'bringing'} en
# the old value of the row is:  {'sandy', 'land', 'look', 'damn', 'yo', 'bringing'}
# the new value of the row is:  {'sandy', 'land', 'look', 'damn', 'yo', 'bringing'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2177 ----
#
#
# Going to tokenize the tweet: Hurricane Sandy in NYC. Prayers to the people and be safe! (Not my pic) #NYC #hurricanesandy #prayers #besaf http://t.co/Mba3bZGl
# The original tweet was: Hurricane Sandy in NYC. Prayers to the people and be safe! (Not my pic) #NYC #hurricanesandy #prayers #besaf http://t.co/Mba3bZGl
#
# The language guesses were: {'id': 2, 'en': 7, 'tl': 1, 'af': 1, 'fi': 1, 'it': 1, 'pl': 1, 'cy': 1, 'lv': 1}
# I predicted the language: en
#
# Returning the values: {'hurricanesandy', 'people', 'prayers', 'sandy', 'pic', 'nyc', 'safe', 'besaf', 'hurricane'} en
# the old value of the row is:  {'hurricanesandy', 'people', 'prayers', 'sandy', 'pic', 'nyc', 'safe', 'besaf', 'hurricane'}
# the new value of the row is:  {'hurricanesandy', 'people', 'prayers', 'sandy', 'pic', 'nyc', 'safe', 'besaf', 'hurricane'}
# result: {'craziest', 'picture', 'ever', 'hurricane'}
#
#
#
# ---- INDEX 2178 ----
#
#
# Going to tokenize the tweet: Apparently the Sandy floodwaters were strong enough to send sharks swimming in your front yar @ Easton Place http://t.co/GjX7sSZE

# %%
modified["tweetText"][5]
# Out:
# '42nd #time #square #NYC #subway #hurricane http://t.co/daX5YY7X'

# %%
modified2["tweetText"][5]
# Out:
# '42nd #time #square #NYC #subway #hurricane http://t.co/daX5YY7X'

# %%
modified.shape
# Out:
# (14277, 2)
